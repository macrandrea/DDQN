# %%
import numpy as np
import pandas as pd
import statistics as stat
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ABM with $\mu = 0 \,\, , \,\, \sigma = 0.1$ : features Q, T and Q,T,P
# ===

# %%
rew = np.load("C:/Users/macri/Desktop/a_grafici/Q_T/0_giusto!/re.npy")
ac  = np.load("C:/Users/macri/Desktop/a_grafici/Q_T/0_giusto!/ac.npy")
ql  = np.load("C:/Users/macri/Desktop/a_grafici/Q_T/0_giusto!/ql.npy")
qud = np.load("C:/Users/macri/Desktop/ennesima/0updn/ql.npy") #qtp

# %%
mu0ac=(20_000 - ac.reshape(-1,5).sum(1))/20_000
mu0ql=(20_000 - ql.reshape(-1,5).sum(1))/20_000
mu0qd=(20_000 - qud.reshape(-1,5)[:2500].sum(1))/20_000
plt.hist(mu0ac, histtype='bar')
plt.hist(mu0ql, histtype='step')
plt.hist(mu0qd, histtype='step')
plt.axvline(mu0ql.mean(), color = 'r' )
plt.axvline(mu0ac.mean(), color = 'g')
plt.axvline(mu0qd.mean(), color = 'y')
;
# Out:
# ''

# %%
plt.hist((((ql.reshape(-1,5).sum(axis = 1) - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1)))*100)
plt.axvline((((ql.reshape(-1,5).sum(axis = 1) - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean()*100, color = 'r')
plt.title('$\Delta \, \, IS$ of QL vs AC, ABM updn $\mu=0,\,\, \sigma=0.1$')
plt.ylabel('iterations')
plt.xlabel('$\Delta \,\, IS$')
plt.annotate(text=' $\Delta \,\, IS$ ave =  -0.0032%', xy = [0.0025,2_000])
plt.annotate(text='  $\Delta \,\, IS$ sd =  0.0017', xy = [0.0025,1_800])
plt.show()

# %%
plt.hist((((qud.reshape(-1,5).sum(axis = 1)   [:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))))
plt.axvline((((qud.reshape(-1,5).sum(axis = 1)[:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean(), color = 'r')
plt.title('$\Delta \, \, IS$ of QL vs AC, ABM updn $\mu=0,\,\, \sigma=0.1$')
plt.ylabel('iterations')
plt.xlabel('$\Delta \,\, IS$')
plt.annotate(text=' $\Delta \,\, IS$ ave =  -0.0032%', xy = [0.0025,2_000])
plt.annotate(text='  $\Delta \,\, IS$ sd =  0.0017', xy = [0.0025,1_800])
plt.show()

# %%
(((qud.reshape(-1,5).sum(axis = 1)[:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean()
# Out:
# -0.00021266298262538958

# %%
(((ql.reshape(-1,5).sum(axis = 1) - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean()
# Out:
# 1.2278171648364974e-05

# %%
mu0ql.mean() - mu0ac.mean(), mu0ql.mean() , mu0ac.mean()
# Out:
# (-1.4590447656136858e-05, 0.0014362367306608827, 0.0014508271783170196)

# %% [markdown]
# ABM with $\mu = 0.001 \,\, , \,\, \sigma = 0.1$ : features Q, T and features Q, T, P
# ===

# %%
rew =   np.load("C:/Users/macri/Desktop/a_grafici/Q_T/0_001/re.npy")
ac =    np.load("C:/Users/macri/Desktop/a_grafici/Q_T/0_001/ac.npy")
ql =    np.load("C:/Users/macri/Desktop/a_grafici/Q_T/0_001/ql.npy")
qud =   np.load("C:/Users/macri/Desktop/a_grafici/Q_T_P/new/0.001updn/ql.npy") #qtp updn
#fai qtp senza updn
#fai quello con 0.001 con q, t, p ma senza up e down

# %%
mu0_001ac  = (20_000 - ac.reshape(-1,5).sum(1))/20_000
mu0_001ql  = (20_000 - ql.reshape(-1,5).sum(1))/20_000
mu0_001qud = (20_000 - qud.reshape(-1,5)[:2500].sum(1))/20_000
plt.hist(mu0_001ac, histtype='bar')
plt.hist(mu0_001ql, histtype='step')
plt.hist(mu0_001qud, histtype='step')
plt.axvline(mu0_001ac.mean(), color = 'r' )
plt.axvline(mu0_001ql.mean(), color = 'g')
plt.axvline(mu0_001qud.mean(), color = 'y')
;
# Out:
# ''

# %%
plt.hist((((ql.reshape(-1,5).sum(axis = 1) - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))))
plt.axvline((((ql.reshape(-1,5).sum(axis = 1) - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean(), color = 'r')
plt.title('$\Delta \, \, IS$ of QL vs AC, ABM updn $\mu=0.001,\,\, \sigma=0.1$')
plt.ylabel('iterations')
plt.xlabel('$\Delta \,\, IS$')
plt.annotate(text=' $\Delta \,\, IS$ ave =  -0.0032%', xy = [0.0025,2_000])
plt.annotate(text='  $\Delta \,\, IS$ sd =  0.0017', xy = [0.0025,1_800])
plt.show()

# %%
(((ql.reshape(-1,5).sum(axis = 1) - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean()
# Out:
# -5.256943182313548e-05

# %%
plt.hist((((qud.reshape(-1,5).sum(axis = 1)   [:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))))
plt.axvline((((qud.reshape(-1,5).sum(axis = 1)[:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean(), color = 'r')
plt.title('$\Delta \, \, IS$ of QL vs AC, ABM updn $\mu=0.001,\,\, \sigma=0.1$')
plt.ylabel('iterations')
plt.xlabel('$\Delta \,\, IS$')
plt.annotate(text=' $\Delta \,\, IS$ ave =  -0.0032%', xy = [0.0025,2_000])
plt.annotate(text='  $\Delta \,\, IS$ sd =  0.0017', xy = [0.0025,1_800])
plt.show()

# %%
(((qud.reshape(-1,5).sum(axis = 1)[:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean()
# Out:
# -0.00020130728072151997

# %%
mu0_001ac.mean() - mu0_001ql.mean(), mu0_001ac.mean() - mu0_001qud.mean(), mu0_001ac.mean() , mu0_001qud.mean()
# Out:
# (-5.731728232504711e-05,
#  -0.00023640192319187734,
#  0.0014009243670846101,
#  0.0016373262902764875)

# %% [markdown]
# ABM with $\mu = -0.001 \,\, , \,\, \sigma = 0.1$ : features Q, T and features Q, T, P
# ===

# %%
rew =   np.load("C:/Users/macri/Desktop/a_grafici/Q_T/-0_001/re.npy")
ac =    np.load("C:/Users/macri/Desktop/a_grafici/Q_T/-0_001/ac.npy")
ql =    np.load("C:/Users/macri/Desktop/a_grafici/Q_T/-0_001/ql.npy")
qud =   np.load("C:/Users/macri/Desktop/-0.001updn/ql.npy") #qtp
#faiqtp senza updn
#fai quello con -0.001 q, t, p ma senza up e down

# %%
mu_0_001ac  = (20_000 - ac.reshape(-1,5).sum(1))/20_000
mu_0_001ql  = (20_000 - ql.reshape(-1,5).sum(1))/20_000
mu_0_001qud = (20_000 - qud.reshape(-1,5)[:2500].sum(1))/20_000
plt.hist(mu_0_001ac, histtype='bar')
#plt.hist(mu0_001ql, histtype='step')
plt.hist(mu_0_001qud, histtype='step')
plt.axvline(mu_0_001ac.mean(), color = 'r' )
plt.axvline(mu_0_001ql.mean(), color = 'g')
plt.axvline(mu_0_001qud.mean(), color = 'y')
;
# Out:
# ''

# %%
mu_0_001ac.mean(), mu_0_001ql.mean(), mu_0_001qud.mean()
# Out:
# (0.0015007299997613962, 0.0016371327625556717, 0.001740142944946394)

# %%
plt.hist((((ql.reshape(-1,5).sum(axis = 1) - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))))
plt.axvline((((ql.reshape(-1,5).sum(axis = 1) - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean(), color = 'r')
plt.title('$\Delta \, \, IS$ of QL vs AC, ABM updn $\mu=-0.001,\,\, \sigma=0.1$')
plt.ylabel('iterations')
plt.xlabel('$\Delta \,\, IS$')
plt.annotate(text=' $\Delta \,\, IS$ ave =  -0.0032%', xy = [0.0025,2_000])
plt.annotate(text='  $\Delta \,\, IS$ sd =  0.0017', xy = [0.0025,1_800])
plt.show()
print((((ql.reshape(-1,5).sum(axis = 1)[:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean())
# Out:
# -0.00012545509511844476

# %%
plt.hist((((qud.reshape(-1,5).sum(axis = 1)   [:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))))
plt.axvline((((qud.reshape(-1,5).sum(axis = 1)[:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean(), color = 'r')
plt.title('$\Delta \, \, IS$ of QL vs AC, ABM updn $\mu=-0.001,\,\, \sigma=0.1$')
plt.ylabel('iterations')
plt.xlabel('$\Delta \,\, IS$')
plt.annotate(text=' $\Delta \,\, IS$ ave =  -0.0032%', xy = [0.0025,2_000])
plt.annotate(text='  $\Delta \,\, IS$ sd =  0.0017', xy = [0.0025,1_800])
plt.show()
print((((qud.reshape(-1,5).sum(axis = 1)[:2500] - ac.reshape(-1,5).sum(axis = 1)) / ac.reshape(-1,5).sum(axis = 1))).mean())
# Out:
# -0.00020499223355598817
